# %%
from pathlib import Path

output_dir = Path.home() / "Documents" / "Mellores_Activity_5"
output_dir.mkdir(parents=True, exist_ok=True)

file_path = output_dir / "Act5_example.txt"

with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.\n")
    file.write("Python makes file handling easy!")

print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\Dexianne\Documents\Mellores_Activity_5\Act5_example.txt

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "Mellores_Activity_5" / "Act5_example.txt"

if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    print("File content:\n", content)

with open(file_path, "r", encoding="utf-8") as file:
    for line_number, line in enumerate(file, 1):
        if "Python" in line:
            print(f"Line {line_number}: {line.strip()}")
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.
# Python makes file handling easy!
# Line 1: Hello, Welcome to Python Programming!
# Line 3: Python makes file handling easy!

# %%
from pathlib import Path

file_path = Path.home() / "Documents" / "Mellores_Activity_5" / "Act5_example.txt"

lines_to_add = [
    "This line was added!",
    "Appending another line.",
]

with open(file_path, "a", encoding="utf-8") as file:
    file.write("\n")
    file.writelines(line + "\n" for line in lines_to_add)

user_input = input("Enter text to append: ")
with open(file_path, "a", encoding="utf-8") as file:
    file.write(user_input + "\n")

print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "Mellores_Activity_5"
backup_dir.mkdir(parents=True, exist_ok=True)

def write_with_backup(filename, content):
    file_path = backup_dir / filename

    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_path = file_path.with_name(
            f"{file_path.stem}_Mellores_backup_{timestamp}{file_path.suffix}"
        )
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")

    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)
        print(f"File saved: {file_path.name}")

def read_file(filename):
    file_path = backup_dir / filename
    with open(file_path, "r", encoding="utf-8") as file:
        return file.read()

print("=== File Operations Demo ===")

print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

print("\n3. Reading file:")
print(read_file("demo.txt"))

print("\n4. Listing backups:")
for backup in backup_dir.glob("*backup*"):
    print("-", backup.name)
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# File saved: demo.txt
#
# 2. Updating file (with backup):
# Backup saved: demo_Mellores_backup_20260509_083126.txt
# File saved: demo.txt
#
# 3. Reading file:
# Updated content
#
# 4. Listing backups:
# - demo_Mellores_backup_20260509_083126.txt

# %%
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "Mellores_Activity_5"
backup_dir.mkdir(parents=True, exist_ok=True)

def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = backup_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. List backups")
        print("6. Exit")

        choice = input("Choose an option (1-6): ")

        if choice == "1":
            content = input("Enter content:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")

        elif choice == "2":
            content = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + content)
            print("Content appended.")

        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")

        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_Mellores_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("File does not exist.")

        elif choice == "5":
            print("\nBackup files:")
            for b in backup_dir.glob("*backup*"):
                print("-", b.name)

        elif choice == "6":
            print("Exiting program.")
            break

        else:
            print("Invalid choice.")

if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. List backups
# 6. Exit
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. List backups
# 6. Exit
#
# File Content:
#  hello
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. List backups
# 6. Exit
# Exiting program.

# %%
from pathlib import Path

student_id = "2025-0586"
student_name = "John Rean - dexter V. Mellores"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!")

print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\Dexianne\Documents\Activity_5_Files\intro_2025-0586.txt

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"

content = file_path.read_text()
print(content)
# Out:
# Welcome John Rean - dexter V. Mellores (ID: 2025-0586) to File Handling in Python!

# %%
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

with file_path.open("a") as f:
    f.write("\nThis is a new line.")

print(f"Line appended to: {file_path}")
# Out:
# Line appended to: C:\Users\Dexianne\Documents\Activity_5_Files\intro_2025-0586.txt

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"lines_{student_id}.txt"

lines = ["Line 1", "Line 2", "Line 3"]

with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: C:\Users\Dexianne\Documents\Activity_5_Files\lines_2025-0586.txt

# %%
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

with file_path.open("r") as f:
    for line in f:
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
from pathlib import Path

student_id = "2025-0586"
student_name = "John Rean - dexter V. Mellores"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

text = file_path.read_text()
word_count = len(text.split())

print(f"{student_name} (ID: {student_id}) - Word count in file '{file_path.name}': {word_count}")
# Out:
# John Rean - dexter V. Mellores (ID: 2025-0586) - Word count in file 'lines_2025-0586.txt': 6

# %%
from pathlib import Path
import shutil

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

src = documents_path / f"intro_{student_id}.txt"
dst = documents_path / f"intro_copy_{student_id}.txt"

shutil.copy(src, dst)

print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File copied successfully from intro_2025-0586.txt to intro_copy_2025-0586.txt.

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

old_file = documents_path / f"intro_copy_{student_id}.txt"
new_file = documents_path / f"intro_renamed_{student_id}.txt"

old_file.rename(new_file)

print(f"File renamed successfully from {old_file.name} to {new_file.name}.")
# Out:
# File renamed successfully from intro_copy_2025-0586.txt to intro_renamed_2025-0586.txt.

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_renamed_{student_id}.txt"

if file_path.exists():
    file_path.unlink()
    print(f"File deleted successfully from: {file_path}")
else:
    print(f"No file found to delete at: {file_path}")
# Out:
# File deleted successfully from: C:\Users\Dexianne\Documents\Activity_5_Files\intro_renamed_2025-0586.txt

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
new_dir = documents_path / f"data_{student_id}"

new_dir.mkdir(parents=True, exist_ok=True)

print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: C:\Users\Dexianne\Documents\Activity_5_Files\data_2025-0586

# %%
import json
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
data_dir = documents_path / f"data_{student_id}"
data_dir.mkdir(parents=True, exist_ok=True)

data = {
    "name": "John Rean - dexter V. Mellores",
    "age": 18,
    "course": "Python Programming"
}

file_path = data_dir / f"student_{student_id}.json"

with file_path.open("w") as f:
    json.dump(data, f, indent=4)

print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: C:\Users\Dexianne\Documents\Activity_5_Files\data_2025-0586\student_2025-0586.json

# %%
import json
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"data_{student_id}" / f"student_{student_id}.json"

with file_path.open("r") as f:
    data = json.load(f)

print(data)
# Out:
# {'name': 'John Rean - dexter V. Mellores', 'age': 18, 'course': 'Python Programming'}

# %%
import csv
from pathlib import Path

student_id = "2025-0586"
student_name = "John Rean - dexter V. Mellores"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"students_{student_id}.csv"

rows = [
    ["Name", "Student ID", "Score"],
    ["Anna", "2025-1001", 90],
    ["Ben", "2025-1002", 85],
    [student_name, student_id, 95]
]

with file_path.open("w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"CSV file created at: {file_path}")
# Out:
# CSV file created at: C:\Users\Dexianne\Documents\Activity_5_Files\students_2025-0586.csv

# %%
import csv
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"students_{student_id}.csv"

with file_path.open("r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Student ID', 'Score']
# ['Anna', '2025-1001', '90']
# ['Ben', '2025-1002', '85']
# ['John Rean - dexter V. Mellores', '2025-0586', '95']

# %%
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"missing_file_{student_id}.txt"

try:
    print(file_path.read_text())
except FileNotFoundError:
    print(f"File not found for Student ID: {student_id}")
# Out:
# File not found for Student ID: 2025-0586

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

txt_files = list(documents_path.glob("*.txt"))

print(f"Student ID: {student_id}")
print(f"Found {len(txt_files)} .txt files in {documents_path}")

for file in txt_files:
    print(file.name)
# Out:
# Student ID: 2025-0586
# Found 2 .txt files in C:\Users\Dexianne\Documents\Activity_5_Files
# intro_2025-0586.txt
# lines_2025-0586.txt

# %%
import time
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

if file_path.exists():
    stat = file_path.stat()
    print(f"Student ID: {student_id}")
    print(f"File: {file_path.name}")
    print(f"Size: {stat.st_size} bytes")
    print(f"Last Modified: {time.ctime(stat.st_mtime)}")
else:
    print(f"File {file_path.name} not found for Student ID: {student_id}")
# Out:
# Student ID: 2025-0586
# File: intro_2025-0586.txt
# Size: 103 bytes
# Last Modified: Sat May  9 08:34:07 2026

# %%
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))

lines = file_path.read_text().splitlines()

with file_path.open("w") as f:
    for i, line in enumerate(lines, 1):
        f.write(f"{i}: {line.upper()}\n")

print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: C:\Users\Dexianne\Documents\Activity_5_Files\lines_2025-0586.txt

# %%
from pathlib import Path

student_id = "2025-0586"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))

lines = file_path.read_text().splitlines()
lines.reverse()

with file_path.open("w") as f:
    f.write("\n".join(lines))

print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: 2025-0586

# %%
from pathlib import Path

student_id = "2025-0586"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

f1 = documents_path / f"intro_{student_id}.txt"
f2 = documents_path / f"lines_{student_id}.txt"
merged = documents_path / f"merged_{student_id}.txt"

if not f1.exists():
    f1.write_text(f"Welcome {student_id} to File Handling in Python!")

if not f2.exists():
    f2.write_text("Line 1\nLine 2\nLine 3")

with merged.open("w") as mf:
    mf.write(f1.read_text())
    mf.write("\n")
    mf.write(f2.read_text())

print(f"Files merged successfully for Student ID: {student_id}")
# Out:
# Files merged successfully for Student ID: 2025-0586
